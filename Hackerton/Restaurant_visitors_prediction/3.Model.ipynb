# %% [markdown]
# # Preparing Dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import xgboost as xgb
import numpy as np

full = pd.read_csv('scratch/full_engineering.csv')

# %%
# train, test 데이터셋 분리
past = full.query('dataset=="past"')
future  = full.query('dataset=="future"')

print('train data set:')
display(past.shape)
display(past.head())

print('test data set:')
display(future.shape)
display(future.head())
# Out:
# train data set:
# (252108, 24)
#   dataset  visitors                               id  weekday  year  month  \
# 0    past        25  air_ba937bf13d40fb24_2016-01-13        2  2016      1
# 1    past        32  air_ba937bf13d40fb24_2016-01-14        3  2016      1
# 2    past        29  air_ba937bf13d40fb24_2016-01-15        4  2016      1
# 3    past        22  air_ba937bf13d40fb24_2016-01-16        5  2016      1
# 4    past         6  air_ba937bf13d40fb24_2016-01-18        0  2016      1
#
#    day_of_year  is_month_end  holiday_flg  tomorrow_is_holiday  ...  \
# 0           13             0            0                    0  ...
# 1           14             0            0                    0  ...
# 2           15             0            0                    0  ...
# 3           16             0            0                    0  ...
# 4           18             0            0                    0  ...
#
#    Todofuken  city  street  n_stores_same_street  n_stores_same_city  \
# 0          7    29      77                    51                  61
# 1          7    29      77                    51                  61
# 2          7    29      77                    51                  61
# 3          7    29      77                    51                  61
# 4          7    29      77                    51                  61
#
#    n_stores_same_Todofuken  n_reserves  n_reserve_visitors  \
# 0                      444         NaN                 NaN
# 1                      444         NaN                 NaN
# 2                      444         NaN                 NaN
# 3                      444         NaN                 NaN
# 4                      444         NaN                 NaN
#
#    reserve_avg_hours_ahead  max_reserve_visitors
# 0                      NaN                   NaN
# 1                      NaN                   NaN
# 2                      NaN                   NaN
# 3                      NaN                   NaN
# 4                      NaN                   NaN
#
# [5 rows x 24 columns]
# test data set:
# (32019, 24)
#        dataset  visitors                               id  weekday  year  \
# 252108  future         0  air_00a91d42b08b08d9_2017-04-23        6  2017
# 252109  future         0  air_00a91d42b08b08d9_2017-04-24        0  2017
# 252110  future         0  air_00a91d42b08b08d9_2017-04-25        1  2017
# 252111  future         0  air_00a91d42b08b08d9_2017-04-26        2  2017
# 252112  future         0  air_00a91d42b08b08d9_2017-04-27        3  2017
#
#         month  day_of_year  is_month_end  holiday_flg  tomorrow_is_holiday  \
# 252108      4          113             0            0                    0
# 252109      4          114             0            0                    0
# 252110      4          115             0            0                    0
# 252111      4          116             0            0                    0
# 252112      4          117             0            0                    0
#
#         ...  Todofuken  city  street  n_stores_same_street  \
# 252108  ...          7     5      45                    20
# 252109  ...          7     5      45                    20
# 252110  ...          7     5      45                    20
# 252111  ...          7     5      45                    20
# 252112  ...          7     5      45                    20
#
#         n_stores_same_city  n_stores_same_Todofuken  n_reserves  \
# 252108                  22                      444         NaN
# 252109                  22                      444         NaN
# 252110                  22                      444         NaN
# 252111                  22                      444         NaN
# 252112                  22                      444         NaN
#
#         n_reserve_visitors  reserve_avg_hours_ahead  max_reserve_visitors
# 252108                 NaN                      NaN                   NaN
# 252109                 NaN                      NaN                   NaN
# 252110                 NaN                      NaN                   NaN
# 252111                 NaN                      NaN                   NaN
# 252112                 NaN                      NaN                   NaN
#
# [5 rows x 24 columns]

# %%
# 불필요한 변수 제거
X = past.drop(columns=['id','dataset','visitors'])

# target 로그 스케일링
y = past['visitors'].apply(np.log1p)

# test 데이터셋
id_col = future['id']
X_test = future.drop(columns=['id','dataset','visitors'])

# %%
# train, val 데이터셋 분리
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
# DMatrix
train_dmatrix = xgb.DMatrix(X_train, label=y_train)
val_dmatrix = xgb.DMatrix(X_val, label=y_val)
X_test = xgb.DMatrix(X_test)

eval_setting = [ (train_dmatrix, 'train'), (val_dmatrix, 'eval') ]

# %%
# %%time

try_xgb_params = {'eta': 0.1,
                  'colsample_bytree': 0.8,
                  'gamma': 0.5,
                  'max_depth': 8,
                  'min_child_weight': 100,
                  'objective': 'reg:squarederror',
                  'seed': 2018,
                  'subsample': 1}

model = xgb.train(params=try_xgb_params,
                  dtrain=train_dmatrix, 
                  num_boost_round=100000, 
                  evals=eval_setting,
                  early_stopping_rounds=50,
                  verbose_eval=100
                 )

best_iteration = model.best_iteration
best_score = model.best_score

print ('best_score: {}, best_iteration: {}'.format(best_score, best_iteration))
# Out:
# [0]	train-rmse:2.32902	eval-rmse:2.33304
# [100]	train-rmse:0.68549	eval-rmse:0.69736
# [200]	train-rmse:0.66496	eval-rmse:0.67965
# [300]	train-rmse:0.65723	eval-rmse:0.67372
# [400]	train-rmse:0.65273	eval-rmse:0.67074
# [500]	train-rmse:0.64856	eval-rmse:0.66824
# [600]	train-rmse:0.64557	eval-rmse:0.66639
# [700]	train-rmse:0.64411	eval-rmse:0.66601
# [800]	train-rmse:0.64250	eval-rmse:0.66529
# [900]	train-rmse:0.64121	eval-rmse:0.66455
# [956]	train-rmse:0.64105	eval-rmse:0.66449
# best_score: 0.664482, best_iteration: 907
# CPU times: user 7min 30s, sys: 23.5 s, total: 7min 53s
# Wall time: 1min 8s

# %%
future['visitors'] = model.predict(X_test)
future['visitors'] = np.expm1(future['visitors'])
# Out:
# <ipython-input-7-097ae3e18bf7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   future['visitors'] = model.predict(X_test)
# <ipython-input-7-097ae3e18bf7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   future['visitors'] = np.expm1(future['visitors'])

# %%
sub = future[['id','visitors']].copy()
sub.to_csv('sub_xgb_try.csv', index=False)

# %%
sub
# Out:
#                                      id   visitors
# 252108  air_00a91d42b08b08d9_2017-04-23  12.417237
# 252109  air_00a91d42b08b08d9_2017-04-24  19.735861
# 252110  air_00a91d42b08b08d9_2017-04-25  22.724957
# 252111  air_00a91d42b08b08d9_2017-04-26  26.968084
# 252112  air_00a91d42b08b08d9_2017-04-27  27.132521
# ...                                 ...        ...
# 284122  air_fff68b929994bfbd_2017-05-27  11.611891
# 284123  air_fff68b929994bfbd_2017-05-28  10.418058
# 284124  air_fff68b929994bfbd_2017-05-29   5.568339
# 284125  air_fff68b929994bfbd_2017-05-30   7.430390
# 284126  air_fff68b929994bfbd_2017-05-31   7.703422
#
# [32019 rows x 2 columns]

# %% [markdown]
# # Model Tuning

# %%
basic_xgb_params = {
    'objective': 'reg:squarederror',
    'eta': 0.1,
    'seed': 2018
}

# %%
search_xgb_params = {
    'max_depth': [4, 8, 12, 16, 20, 24, 28, 32],
    'gamma': [0, 0.1, 0.2, 0.5, 1, 1.5, 2, 3],
    'colsample_bytree': [0.1, 0.2, 0.4, 0.6, 0.8, 1],
    'subsample': [0.1, 0.2, 0.4, 0.6, 0.8, 1],
    'min_child_weight': [0, 1, 3, 10, 20, 30, 50, 100]
}

# %%
# %%time

best_params = basic_xgb_params.copy()

for p in search_xgb_params:  
    print('Tuning parameter {}, range: {}'.format(p, search_xgb_params[p]))
    test_params = best_params
    scores = []
    
    for v in search_xgb_params[p]:    
        test_params[p] = v
        test_model = xgb.train(params=test_params, 
                               dtrain=train_dmatrix, 
                               num_boost_round=100000, 
                               evals=eval_setting,
                               early_stopping_rounds=50,
                               verbose_eval=False
                              )
        best_iter = test_model.best_iteration
        best_score = test_model.best_score
        scores.append([v, best_score])
        print('    {p}={v}: best_score={s}, best_iter={it}'.format(p=p, v=v, s=best_score, it=best_iter))
        
    scores.sort(key=lambda x: x[1])
    best_value = scores[0][0]
    best_score = scores[0][1]
    best_params[p] = best_value
    print('  Best value for {p}: {v} (score {s})'.format(p=p, v=best_value, s=best_score))
        
print(best_params)
# Out:
# Tuning parameter max_depth, range: [4, 8, 12, 16, 20, 24, 28, 32]
#     max_depth=4: best_score=0.667849, best_iter=2857
#     max_depth=8: best_score=0.665771, best_iter=280
#     max_depth=12: best_score=0.671893, best_iter=53
#     max_depth=16: best_score=0.690279, best_iter=34
#     max_depth=20: best_score=0.718402, best_iter=29
#     max_depth=24: best_score=0.741959, best_iter=26
#     max_depth=28: best_score=0.757558, best_iter=25
#     max_depth=32: best_score=0.762604, best_iter=24
#   Best value for max_depth: 8 (score 0.665771)
# Tuning parameter gamma, range: [0, 0.1, 0.2, 0.5, 1, 1.5, 2, 3]
#     gamma=0: best_score=0.665771, best_iter=280
#     gamma=0.1: best_score=0.665249, best_iter=267
#     gamma=0.2: best_score=0.665451, best_iter=298
#     gamma=0.5: best_score=0.665044, best_iter=232
#     gamma=1: best_score=0.671152, best_iter=139
#     gamma=1.5: best_score=0.672393, best_iter=130
#     gamma=2: best_score=0.670254, best_iter=147
#     gamma=3: best_score=0.671619, best_iter=128
#   Best value for gamma: 0.5 (score 0.665044)
# Tuning parameter colsample_bytree, range: [0.1, 0.2, 0.4, 0.6, 0.8, 1]
#     colsample_bytree=0.1: best_score=0.675901, best_iter=2165
#     colsample_bytree=0.2: best_score=0.669391, best_iter=733
#     colsample_bytree=0.4: best_score=0.666124, best_iter=625
#     colsample_bytree=0.6: best_score=0.665294, best_iter=515
#     colsample_bytree=0.8: best_score=0.664361, best_iter=367
#     colsample_bytree=1: best_score=0.665044, best_iter=232
#   Best value for colsample_bytree: 0.8 (score 0.664361)
# Tuning parameter subsample, range: [0.1, 0.2, 0.4, 0.6, 0.8, 1]
#     subsample=0.1: best_score=0.68114, best_iter=260
#     subsample=0.2: best_score=0.673982, best_iter=261
#     subsample=0.4: best_score=0.669966, best_iter=251
#     subsample=0.6: best_score=0.667601, best_iter=249
#     subsample=0.8: best_score=0.665246, best_iter=280
#     subsample=1: best_score=0.664361, best_iter=367
#   Best value for subsample: 1 (score 0.664361)
# Tuning parameter min_child_weight, range: [0, 1, 3, 10, 20, 30, 50, 100]
#     min_child_weight=0: best_score=0.664361, best_iter=367
#     min_child_weight=1: best_score=0.664361, best_iter=367
#     min_child_weight=3: best_score=0.66532, best_iter=454
#     min_child_weight=10: best_score=0.663696, best_iter=529
#     min_child_weight=20: best_score=0.664231, best_iter=373
#     min_child_weight=30: best_score=0.663329, best_iter=541
#     min_child_weight=50: best_score=0.663782, best_iter=561
#     min_child_weight=100: best_score=0.662609, best_iter=1086
#   Best value for min_child_weight: 100 (score 0.662609)
# {'objective': 'reg:squarederror', 'eta': 0.1, 'seed': 2018, 'max_depth': 8, 'gamma': 0.5, 'colsample_bytree': 0.8, 'subsample': 1, 'min_child_weight': 100}
# CPU times: user 2h 54min 51s, sys: 8min 54s, total: 3h 3min 45s
# Wall time: 27min 57s
